# %%
import os
from langchain.chat_models import init_chat_model
from dotenv import load_dotenv

load_dotenv(override=True)
AI_API_KEY = os.getenv("AI_API_KEY")

AI_BASE_URL = os.getenv("AI_BASE_URL")

deepseek = init_chat_model(
    api_key=AI_API_KEY,
    model='deepseek-flash',
    base_url=AI_BASE_URL,
    temperature=0.7,
)
prompt = input('请输入你的问题：')
response = deepseek.invoke(prompt)
print(response.pretty_print())
# Out:
# ================================== Ai Message ==================================
#
# I see “11.” What would you like me to do with it?
# None

# %%
import os
from langchain.chat_models import init_chat_model
from dotenv import load_dotenv

load_dotenv(override=True)
AI_API_KEY = os.getenv("AI_API_KEY")

AI_BASE_URL = os.getenv("AI_BASE_URL")

deepseek = init_chat_model(
    api_key=AI_API_KEY,
    model='deepseek-flash',
    base_url=AI_BASE_URL,
    temperature=0.7,
    max_tokens=1024,
)
prompt = '你是什么模型 可以做什么'
response = deepseek.invoke(prompt)
print(response.content)
# Out:
# 我是 **ChatGPT**，一个由 OpenAI 训练的大型语言模型 AI 助手。具体版本会取决于你当前使用的平台或界面设置。
#
# 我可以帮你做很多文字和知识类任务，例如：
#
# - **回答问题**：解释概念、查资料思路、给建议
# - **写作**：文章、邮件、文案、报告、故事、润色改写
# - **翻译**：中英互译、多语言翻译、语气调整
# - **学习辅导**：数学、物理、编程、语言学习等
# - **编程**：写代码、调试、解释代码、设计算法
# - **总结整理**：长文总结、提取重点、做表格/清单
# - **创意脑暴**：起名、策划、点子、脚本、标题
# - **规划**：学习计划、旅行计划、工作计划、时间管理
# - **逻辑推理**：分析问题、比较方案、辅助决策
#
# 我的限制是：如果没有联网或工具支持，我不能保证获取实时信息；也不能代替医生、律师、财务顾问等专业意见，也不能直接操作现实世界。
#
# 你可以直接告诉我你想做什么，我来帮你。
