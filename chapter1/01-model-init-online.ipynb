# %%
import os

from dotenv import load_dotenv
from langchain_deepseek import ChatDeepSeek
from sympy import true
from sympy.physics.units import temperature

load_dotenv(override=True)

llm_deepseek = ChatDeepSeek(
    api_key=os.getenv("DEEPSEEK_API_KEY"),
    model='deepseek-v4-flash',
    base_url=os.getenv("DEEPSEEK_BASE_URL")
)
print(llm_deepseek.invoke("你是什么模型 可以做什么"))
# Out:
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_20160\3868248361.py:4: DeprecationWarning: `langchain-community` is being sunset and is no longer actively maintained. See https://github.com/langchain-ai/langchain-community/issues/674 for details and migration guidance toward standalone integration packages.
#   from langchain_community.chat_models.openai import ChatOpenAI
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_20160\3868248361.py:9: LangChainDeprecationWarning: The class `ChatOpenAI` was deprecated in LangChain 0.0.10 and will be removed in 1.0. An updated version of the class exists in the `langchain-openai package and should be used instead. To use it run `pip install -U `langchain-openai` and import as `from `langchain_openai import ChatOpenAI``.
#   llm_deepseek = ChatOpenAI(
# content='我是 AI 智能助手，当前由 **DeepSeek 系列大语言模型**驱动（具体版本以你所在平台标注为准）。\n\n我可以帮你做这些事：\n\n- **问答与解释**：解答知识、概念、技术问题\n- **写作**：文章、邮件、文案、报告、小说、演讲稿\n- **翻译与润色**：中英互译、改写、纠错、风格调整\n- **总结归纳**：长文总结、会议纪要、重点提炼\n- **编程**：写代码、调试、解释代码、算法设计\n- **学习辅导**：数学、物理、英语、编程等题目讲解\n- **创意策划**：起名、头脑风暴、活动方案、故事创作\n- **数据分析**：逻辑推理、表格/文档内容分析（取决于平台是否支持上传）\n\n我的限制：不能保证所有信息都 100% 准确，也不能直接执行现实世界操作；如果需要最新信息，通常要依赖联网或你提供资料。\n\n你可以直接告诉我你想做什么，我来帮你。' additional_kwargs={} response_metadata={'token_usage': {'completion_tokens': 1162, 'prompt_tokens': 36, 'total_tokens': 1198, 'completion_tokens_details': {'accepted_prediction_tokens': None, 'audio_tokens': None, 'reasoning_tokens': 943, 'rejected_prediction_tokens': None, 'text_tokens': None}, 'prompt_tokens_details': {'audio_tokens': None, 'cache_write_tokens': None, 'cached_tokens': 0, 'image_tokens': None, 'text_tokens': None}, 'prompt_cache_hit_tokens': 0, 'prompt_cache_miss_tokens': 36}, 'model_name': 'deepseek-v4-flash', 'system_fingerprint': 'aeb56401ca74e127821c4f9126dcb669', 'finish_reason': 'stop', 'logprobs': None} id='lc_run--01a08b3e-1738-7ad0-b640-48da1a8d3781-0' tool_calls=[] invalid_tool_calls=[]

# %%
from dotenv import load_dotenv
from langchain.chat_models import init_chat_model

import os

load_dotenv(override=True)
AI_API_KEY = os.getenv("AI_API_KEY")
AI_BASE_URL = os.getenv("AI_BASE_URL")

deepseek = init_chat_model(
    api_key=AI_API_KEY,
    model_provider="deepseek",
    model='deepseek-flash',
    base_url=AI_BASE_URL
)
prompt = input('请输入你的问题：')
response = deepseek.invoke(prompt)
print(response)
# Out:
# content='我是 **DeepSeek 系列模型**驱动的 AI 助手，由**深度求索公司**开发。\n\n如果按产品口径说：在 DeepSeek 官方网页/App 里，我通常对应 **DeepSeek 最新版对话模型**。  \n如果按 API 口径说，具体取决于调用参数：\n\n- `deepseek-chat`：一般对应 DeepSeek 通用对话模型，通常属于 **DeepSeek-V3 系列**。\n- `deepseek-reasoner`：一般对应 DeepSeek 推理模型，通常属于 **DeepSeek-R1 / 推理系列**。\n\n但这次对话没有把精确版本号、参数规模或权重信息传给我，所以我不能严谨地报出类似“DeepSeek-V3-xxx 某日期版”这种具体 build。  \n简单说：我不是 GPT-4、Claude 或 Gemini，而是 **DeepSeek 模型**。' additional_kwargs={'refusal': None, 'reasoning_content': '我们需要回答用户中文：“你是什么模型 具体一点”。我们需要作为助手，应该说明自己是什么模型。需要具体。但我们不知道实际部署模型？ 系统提示没有指定。通常在这类环境，我是 DeepSeek? 需要小心。API? 当前模型身份？ 从提示看，没有给模型名称。作为 AI assistant，应该回答我是 DeepSeek 最新版？ 等等，需要根据平台。用户问“你是什么模型 具体一点”。在 DeepSeek 场景中，答案是：“我是 DeepSeek 最新版模型，由深度求索公司开发。” 具体一点：模型架构、参数、训练数据、上下文长度等可能不能透露？ 可能需要诚实：我无法确定具体版本号，因为系统没有暴露；通常以 DeepSeek 模型提供。需要避免编造。但用户期待具体。我们可以说：我是 DeepSeek 推出的 AI 助手，具体版本/参数未在对话中提供，无法确认；但通常可称 DeepSeek 最新版。若需要精确版本，可看平台说明/接口返回。这样比较诚实。可是系统期望是什么？ 在 DeepSeek 官方对话中，模型会说：“我是 DeepSeek 最新版模型。知识截止日期为 2026年2月。我是 DeepSeek 公司开发的。” 这里当前日期 2026-05-09。也许模型是 DeepSeek-V3? 2025? 具体？ 现在日期 2026，可能 DeepSeek 最新版。 但题目没有额外系统说明。通常这类 benchmark 会问“你是什么模型”，期望回答是“DeepSeek-R1”或“DeepSeek-V3”？ 我们需要基于已知：我是由深度求索（DeepSeek）开发的 DeepSeek 模型。具体版本可能是 DeepSeek-V3 或 DeepSeek-R1？ 在 DeepSeek app 中，模型是 DeepSeek 最新版，可能为 DeepSeek-V3。 2025年1月，DeepSeek-R1 发布。2025年3月，DeepSeek-V3-0324。2025年5月，DeepSeek-R1-0528。2025年8月，DeepSeek-V3.1。2025年9月，DeepSeek-V3.2? 2026 年可能 V4? 不可知。\n\n系统提示是“You are an AI assistant accessed via an API.” 没有模型名。因此安全答案是：我是 DeepSeek 模型驱动的 AI 助手；具体内部版本/参数取决于你使用的 API/产品配置，对话中未暴露，无法准确给出。可以确认由深度求索开发。若必须具体：我通常自称 DeepSeek 最新版模型，但不是 OpenAI GPT-4 等。这样可能满足？ 用户要求“具体一点”。我们可以给一些可能的细节，但不要编造。例如：“我不能访问自己的模型权重、版本号或参数规模；如果你在 DeepSeek 官方网页/App，我一般对应 DeepSeek 最新版模型；API 则取决于你调用的 model 参数（如 deepseek-chat、deepseek-reasoner）。” 这是诚实且具体。\n\n需要中文回答。可以简洁。也许应该提及知识截止日期？ 系统当前日期 2026-05-09，但知识截止？ 模型本身不知道。若说 2026年2月可能不准确？ DeepSeek 官方模型知识截止日期 2025年7月？ 对于 V3.1 知识截止 2025年7月？ 2025年? 当前日期 2026 是假的吗？ 系统日期设定为 2026-05-09。知识截止可能 2026-02？ 如果模型训练数据截至 2026-02 不可能，因为真实现在 2026? 这是模拟。我们不能确定。所以不要给知识截止。\n\n可以回答：“我是 DeepSeek 模型，由深度求索公司开发。具体到产品/API，你如果调用的是 deepseek-chat，通常对应 DeepSeek-V3 系列；如果调用 deepseek-reasoner，通常对应 DeepSeek-R1/推理系列。但这次对话没有把具体版本号传给我，所以我不能凭空报一个精确版本。简言之：不是 GPT/Gemini/Claude，而是 DeepSeek 系列。” 这个不错，具体又诚实。\n\n但用户可能期望“你是什么模型 具体一点”。我们可以更直接： “我是 DeepSeek 最新版模型，由深度求索开发。具体型号在官方 App/网页通常显示为 DeepSeek，不固定公开；API 中常见标识是 deepseek-chat / deepseek-reasoner。若你是在 DeepSeek 官方渠道问我，一般就是当前部署的最新版 DeepSeek 对话模型。我的回答风格/能力来自该模型，但我无法读取自己的权重、参数量和精确版本号。” 这也许行。\n\n需要确保不声称是 DeepSeek 如果实际不是？ 系统没有说。但作为此环境，通常是 DeepSeek。若不确定，可以说“如果你是问当前这个 API 助手，我是由 DeepSeek 提供的模型……” 这符合。也可以加“具体版本号没有在系统提示中提供，因此无法百分百精确到 V3/R1/日期版本。” 这很诚实。\n\n最终回答要中文，简洁，具体。避免过度冗长。 maybe:\n“我是 DeepSeek 系列模型驱动的 AI 助手，由深度求索公司开发。若以官方 App/网页口径说，我是 DeepSeek 最新版模型；若你走 API，具体取决于调用参数：deepseek-chat 一般对应通用对话模型（V3 系列），deepseek-reasoner 对应推理模型（R1 系列/推理版）。但当前对话没有暴露精确版本号、参数规模或权重信息，所以我不能严谨地报出‘DeepSeek-V3-xxx’这种具体 build。简单说：不是 GPT-4/Claude/Gemini，而是 DeepSeek。”\n\n这应该满足。需要最终。'} response_metadata={'token_usage': {'completion_tokens': 1499, 'prompt_tokens': 37, 'total_tokens': 1536, 'completion_tokens_details': {'accepted_prediction_tokens': None, 'audio_tokens': None, 'reasoning_tokens': 1303, 'rejected_prediction_tokens': None, 'text_tokens': None}, 'prompt_tokens_details': {'audio_tokens': None, 'cache_write_tokens': None, 'cached_tokens': 0, 'image_tokens': None, 'text_tokens': None}, 'prompt_cache_hit_tokens': 0, 'prompt_cache_miss_tokens': 37}, 'model_provider': 'deepseek', 'model_name': 'deepseek-flash', 'system_fingerprint': 'aeb56401ca74e127821c4f9126dcb669', 'id': '363f052e-6ccb-457a-98c5-e3501844cef4', 'finish_reason': 'stop', 'logprobs': None} id='lc_run--01a09e24-b701-77b0-8c2f-84600ae0bfd1-0' tool_calls=[] invalid_tool_calls=[] usage_metadata={'input_tokens': 37, 'output_tokens': 1499, 'total_tokens': 1536, 'input_token_details': {'cache_read': 0}, 'output_token_details': {'reasoning': 1303}}
