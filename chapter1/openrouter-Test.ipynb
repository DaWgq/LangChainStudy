# %%
import os
from langchain.chat_models import init_chat_model
from dotenv import load_dotenv

load_dotenv(override=True)
AI_API_KEY = os.getenv("openrouter_key")

AI_BASE_URL = os.getenv("openrouter_url")

openrouter = init_chat_model(
    model_provider="openrouter",
    api_key=AI_API_KEY,
    model='nvidia/nemotron-3.5-lightning:free',
    base_url=AI_BASE_URL,
    temperature=0.7,
    max_tokens=1024,
)
prompt = '人生的意义是什么'
response = openrouter.stream(prompt)
for i in response:
    print(i.text,end='',flush=True)
# Out:
# Here's a thinking process:
#
# 1.  **Analyze User Input:**
#    - User asks: "人生的意义是什么" (What is the meaning of life?)
#    - This is a classic, profound, open-ended philosophical question.
#    - No specific context, personal details, or constraints given.
#
# 2.  **Identify Core Task:**
#    - Provide a thoughtful, comprehensive, and balanced answer to "What is the meaning of life?"
#    - Should cover multiple perspectives: philosophical, religious, scientific, personal, etc.
#    - Should avoid being preachy or definitive, since there's no single objective answer.
#    - Should be culturally sensitive (Chinese context implied by the language, but keep it universal).
#
# 3.  **Determine Key Perspectives/Frameworks:**
#    - **Philosophical:** Existentialism (Sartre, Camus), Nihilism, Stoicism, Aristotle's Eudaimonia
#    - **Religious/Spiritual:** Purpose given by deity, enlightenment, karma, afterlife
#    - **Scientific/Evolutionary:** Survival, reproduction, passing on genes, understanding the universe
#    - **Humanistic/Psychological:** Connection, growth, contribution, happiness, meaning-making
#    - **Personal/Subjective:** Creating one's own meaning, as per existentialism
#
# 4.  **Structure the Response:**
#    - Acknowledge the depth/openness of the question
#    - Present major frameworks concisely
#    - Emphasize the personal/subjective aspect
#    - Offer a concluding reflective thought
#    - Keep it respectful, inclusive, and not dogmatic
#
#    Structure:
#    - Introduction: No single answer, it's a journey
#    - Perspective 1: Philosophical (Existentialism, Nihilism, Stoicism, Aristotle)
#    - Perspective 2: Scientific/Evolutionary
#    - Perspective 3: Religious/Spiritual
#    - Perspective 4: Psychological/Humanistic (connection, growth, contribution)
#    - Perspective 5: The "Create Your Own Meaning" approach
#    - Conclusion: Invite the user to reflect on their own values
#
# 5.  **Draft - Mental Refinement (incorporating key points):**
#    (I'll write it out in Chinese since the question is in Chinese, but I can also include some English context if needed. I'll stick to Chinese.)
#
#    注意：人生的意义没有标准答案，因人而异，因时而异。以下是几种常见的视角供参考：
#
#    1. **存在主义视角**：意义不先于存在，而是由人自己创造。萨特说“人是一团随方向飘荡的火焰”，我们通过行动和选择赋予生活意义。加缪则谈“反抗”与在荒谬中寻找乐趣。
#
#    2. **亚里士多德/德育观**：追求幸福不是短暂的快感，而是过上有德行、有目标的生活（eudaimonia）。通过成长、贡献和实现潜能来获得深层满足。
#
#    3. **进化生物学视角**：从基础层面看，生命的意义可能是生存、繁衍和传递基因。但这并不妨碍我们在文化、精神层面追求更高的目标。
#
#    4. **宗教/灵性视角**：许多人认为生命的意义源于神圣的旨意、宇宙的秩序或灵魂的进化。这提供了确定感、道德指引和超越性的体验。
#
#    5. **人文/心理学视角**：意义常通过三种途径体现：① 连接（爱、亲情、友谊），② 贡献（创作、工作、帮助他人），③ Growth（成长、自我超越）。维克多·弗兰克尔在《活出生命的意义》中强调，即使在最艰难处境中，人也能通过态度和选择找到意义。
#
#    6. **“自创意义”**：最自由的观点或许是：生活本身没有预设意义，但这也意味着你有完全的自由去定义什么对你是重要的——无论是艺术、旅行、抚育后代、学习一项技能，还是仅仅是享受当下。
#
#    结语：人生的意义或许不是一个终点，而是一个不断提问、试错、成长的过程。你可以问自己：什么让我感到充
