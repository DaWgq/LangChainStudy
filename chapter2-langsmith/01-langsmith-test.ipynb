# %% [markdown]
# # 示例

# %%
import os
from langchain.chat_models import init_chat_model
from dotenv import load_dotenv

load_dotenv(override=True)
AI_API_KEY = os.getenv("AI_API_KEY")

AI_BASE_URL = os.getenv("AI_BASE_URL")

deepseek = init_chat_model(
    api_key=AI_API_KEY,
    model='deepseek-flash',
    base_url=AI_BASE_URL,
    temperature=0.7,
    max_tokens=1024,
)
prompt = '你是什么模型 可以做什么'
response = deepseek.invoke(prompt)
print(response.content)
# Out:
# 我是一个 **AI 对话助手**，由大语言模型驱动。具体底层模型名称和版本，通常以你所在平台/产品的说明为准；我这边无法自行确认。
#
# 我可以帮你做这些事：
#
# - **问答与解释**：解释概念、科普知识、分析问题、提供思路。
# - **写作与润色**：写文章、邮件、文案、报告、总结、简历、演讲稿，修改语气和措辞。
# - **翻译**：中英互译、多语言翻译、术语统一、本地化表达。
# - **编程**：生成代码、解释代码、调试报错、写测试、优化性能、SQL/Shell/正则等。
# - **学习辅导**：讲解题目、梳理知识点、制定学习计划、出练习题。
# - **信息整理**：提炼重点、做表格、列大纲、对比方案、生成清单。
# - **创意生成**：起名、故事、诗歌、广告语、头脑风暴、产品点子。
# - **分析与决策**：优缺点分析、风险评估、方案对比、逻辑推理。
# - **文件/内容处理**：如果当前平台支持上传，我可以帮你阅读和总结文档内容。
#
# 我不能做的事或需要注意：
#
# - 不能直接操作现实世界，比如打电话、下单、发邮件。
# - 不联网时无法获取实时信息；是否联网取决于当前平台功能。
# - 可能出错，重要信息建议核实。
# - 不能替代医生、律师、金融等专业意见。
#
# 你可以直接告诉我目标，比如：
# “帮我写一封辞职邮件”“解释这段代码”“把这篇长文总结成 5 点”“给我一个学习 Python 的计划”。
